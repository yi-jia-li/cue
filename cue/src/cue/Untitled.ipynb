# %%
try:
    from pkg_resources import resource_filename, resource_listdir
except(ImportError):
    pass

# %%
from cue.cont_pca import SpectrumPCA
# Out:
# /gpfs/group/jql6565/default/yli/envs/python3.7-c3k/lib/python3.7/site-packages/cue/utils.py:42: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   ['S  4'], ['Ar 4'], ['Ne 3'], ['Ne 4']])
# /gpfs/group/jql6565/default/yli/envs/python3.7-c3k/lib/python3.7/site-packages/cue/utils.py:54: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   nn_wav_selection = np.array(nn_wav_selection)

# %%
from cont_pca import SpectrumPCA
from nn import Speculator
#cont_speculator = Speculator(restore = True, restore_filename = resource_filename("cue", "data/speculator_cont_new"))
# Out:
# 2023-06-04 05:01:32.896920: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-06-04 05:02:04.563395: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /opt/aci/apps/anaconda3/2020.07_gcc-4.8.5/lib:/storage/home/yzl466/work/julia_install/julia-1.0.2/lib/julia:/storage/home/yzl466/work/julia_install/julia-1.0.2/lib:/opt/aci/apps/python/3.6.3_anaconda-5.0.1/lib:/usr/local/cuda-11.2/lib
# ...

# %%
import dill as pickle
with open(resource_filename("cue", "data/pca_line_new_"+this_name+".pkl", 'rb')) as f:
        globals()["PCABasis_"+this_name] = pickle.load(f)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_17822/1673253834.py in <module>
#       1 import dill as pickle
# ----> 2 with open(resource_filename("cue", "data/pca_line_new_"+this_name+".pkl", 'rb')) as f:
#       3         globals()["PCABasis_"+this_name] = pickle.load(f)
#
# NameError: name 'resource_filename' is not defined

# %%
speculator_cont = Speculator(restore=True,
                             restore_filename="/gpfs/group/jql6565/default/yli/nebular/speculator_cont_new")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_9717/1512458910.py in <module>
#       1 speculator_cont = Speculator(restore=True,
# ----> 2                              restore_filename="/gpfs/group/jql6565/default/yli/nebular/speculator_cont_new")
#
# /gpfs/group/jql6565/default/yli/software/cue/src/cue/nn.py in __init__(self, n_parameters, wavelengths, pca_transform_matrix, parameters_shift, parameters_scale, pca_shift, pca_scale, log_spectrum_shift, log_spectrum_scale, n_hidden, restore, restore_filename, trainable, optimizer)
#      36         # restore
#      37         if restore is True:
# ---> 38             self.restore(restore_filename)
#      39
#      40         # else set variables from input parameters
#
# /gpfs/group/jql6565/default/yli/software/cue/src/cue/nn.py in restore(self, filename)
# ...

# %%
import glob
par_files = glob.glob("/gpfs/group/jql6565/default/yli/nebular/train_new/*.pars")[:2]
par_files
# Out:
# ['/gpfs/group/jql6565/default/yli/nebular/train_new/PowerLaw1758001-1758500.pars',
#  '/gpfs/group/jql6565/default/yli/nebular/train_new/PowerLaw101501-102000.pars']

# %%
tmp = list()
tmp.append(np.vstack([np.loadtxt(par_files[j])[:,[2,3,4,5,6,7,8,11,12,14,15,16]] 
           for j in np.arange(2)]))
tmp.append(np.vstack([np.loadtxt(par_files[j])[:,[2,3,4,5,6,7,8,11,12,14,15,16]] 
           for j in np.arange(2)]))

# %%
import dill as pickle
pickle.load(open("/gpfs/group/jql6565/default/yli/nebular/speculator_line_new_N.pkl", "rb"))
# Out:
# [ListWrapper([array([[-0.07118974, -0.00387367,  0.01019958, ...,  0.00373314,
#          -0.0568583 , -0.01268931],
#         [ 0.22204311, -0.00410887, -0.00235773, ..., -0.00354753,
#           0.04440515,  0.02440288],
#         [-0.03327229, -0.01919406,  0.02352926, ..., -0.02028734,
#           0.12925778, -0.13679697],
#         ...,
#         [ 0.05858559, -0.03178447,  0.0125259 , ...,  0.030659  ,
#           0.14880928, -0.08531798],
#         [ 0.30931556, -0.17669937,  0.00636257, ..., -0.37737307,
#          -0.09752156,  0.28023902],
#         [-0.42017663,  0.35090208,  0.0286259 , ..., -0.521634  ,
#          -0.03357767,  0.07350737]], dtype=float32), array([[-0.64308804,  0.6194809 , -0.21534058, ..., -0.3563387 ,
#           0.5255264 , -0.985108  ],
#         [ 0.5886443 ,  0.2142389 ,  0.34908348, ...,  0.17642312,
#           0.46747833, -0.25903985],
#         [ 0.02713152, -0.15390764,  0.07836514, ..., -0.07609127,
#           0.6885979 ,  0.43752584],
# ...
