# %%
from cue.line import predict as line_predict
from cue.continuum import predict as cont_predict
# Out:
# 2024-11-25 15:54:45.820837: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-11-25 15:54:45.826176: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-11-25 15:54:45.838028: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-11-25 15:54:45.854799: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-11-25 15:54:45.859789: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-11-25 15:54:45.875364: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-11-25 15:54:46.656315: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# /home/annalena/miniconda3/envs/cue/lib/python3.12/site-packages/sklearn/base.py:376: InconsistentVersionWarning: Trying to unpickle estimator IncrementalPCA from version 1.0.2 when using version 1.5.2. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(

# %%
par = [[21.5, 14.85, 6.45, 3.15, 4.55, 0.7, 0.85, 49.58, 10**2.5, -0.85, -0.134, -0.134]]
lines = line_predict(theta=par).nn_predict()
cont = cont_predict(theta=par).nn_predict()

# %%
print(cont)
# Out:
# (array([9.150e+02, 9.250e+02, 9.350e+02, ..., 9.817e+07, 9.908e+07,
#        1.000e+08]), array([8.03521228e+21, 7.99997609e+21, 7.96546856e+21, ...,
#        4.75867714e+23, 4.76413676e+23, 4.76965666e+23]))

# %%
import matplotlib.pyplot as plt

plt.figure()
plt.plot(cont[0], cont[1], label='Continuum')
plt.show()
